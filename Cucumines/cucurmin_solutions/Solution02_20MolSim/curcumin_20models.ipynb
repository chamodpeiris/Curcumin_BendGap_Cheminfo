# %%
# %reset -f
import rdkit
import pycaret
import joblib

print('rdkit: %s' % rdkit.__version__)
print('pycaret: %s' % pycaret.__version__)
print('joblib: %s' % joblib.__version__)
# Out:
# rdkit: 2023.09.5
# pycaret: 3.2.0
# joblib: 1.3.2

# %%
# %%time
import pandas as pd
import numpy as np
from rdkit import Chem, DataStructs
from rdkit.Chem import AllChem, MACCSkeys, Descriptors

# Defining the SMILES strings for the cucumin varients
curcumin_variants = (
    "COc3cc(OC)c(C/C=C/C2=CC(/C=C/Cc1c(OC)cc(OC)cc1OC)=[O+][B-](F)(F)O2)c(OC)c3",
    "COc3ccc(C/C=C/C2=[O+][B-](F)(F)OC(/C=C/Cc1c(OC)cc(OC)cc1OC)=C2)cc3",
    "COc3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(OC)cc1OC)=[O+][B-](F)(F)O2)c(OC)c3",
    "COc5ccc(C/C=C/C4=[O+][B-](F)(F)OC(/C=C/Cc2c1ccccc1cc3ccccc23)=C4)cc5",
    "COc3ccc(OC)c(C/C=C/C2=CC(/C=C/Cc1cc(OC)ccc1OC)=[O+][B-](F)(F)O2)c3",
    "COc3cc(C/C=C/C2=CC(/C=C/Cc1ccc(O)c(OC)c1)=[O+][B-](F)(F)O2)ccc3O",
    "F[B-]3(F)OC(/C=C/Cc1ccc(Br)cc1)=CC(/C=C/Cc2ccc(Br)cc2)=[O+]3",
    "C=C(OC)c3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(C(=C)OC)cc1)=[O+][B-](F)(F)O2)cc3",
    "C=C(OC)c3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(C(=C)OC)cc1)=[O+][B-](F)(F)O2)cc3",
    "CN(C)c3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(N(C)C)cc1)=[O+][B-](F)(F)O2)cc3",
    "CCCOc1cc(N(CC)CC)ccc1C/C=C/C3=CC(/C=C/Cc2ccc(N(CC)CC)cc2OCCC)=[O+][B-](F)(F)O3",
    "CCCOc1cc(N(CC)CC)ccc1C/C=C/C3=CC(/C=C/Cc2ccc(N(CC)CC)cc2OCCC)=[O+][B-](F)(F)O3",
    "N#Cc3ccc(C/C=C/C2=[O+][B-](F)(F)OC(/C=C/Cc1ccccc1)=C2)cc3",
    "COc6ccc(C/C=C/C5=CC(/C=C/Cc1cc2ccc3cccc4ccc(c1)c2c34)=[O+][B-](F)(F)O5)cc6",
    "COc4ccc(C/C=C/C3=CC(/C=C/Cc1ccc(OC)c2ccccc12)=[O+][B-](F)(F)O3)c5ccccc45",
    "CN(C)c4ccc(C/C=C/C3=CC(/C=C/Cc1ccc(N(C)C)c2ccccc12)=[O+][B-](F)(F)O3)c5ccccc45",
    "N#Cc3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(C#N)cc1)=[O+][B-](F)(F)O2)cc3",
    "CCCCN(CCCC)c3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(N(CCCC)CCCC)cc1)=[O+][B-](F)(F)O2)cc3",
    "COc3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(C#N)cc1)=[O+][B-](F)(F)O2)cc3",
    "CN5/C(=C\C\C=C\C3=CC(/C=C/C/C=C/2N(C)c1ccccc1C2(C)C)=[O+][B-](F)(F)O3)C(C)(C)c4ccccc45",
    "COc3ccc(C/C=C/C2=[O+][B-](F)(F)OC(/C=C/Cc1ccc(SC)cc1)=C2)cc3",
    "CSc3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(SC)cc1)=[O+][B-](F)(F)O2)cc3",
    "COc3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(N(C)C)cc1)=[O+][B-](F)(F)O2)cc3",
    "COc5ccc(C/C=C/C4=[O+][B-](F)(F)OC(/C=C/Cc3ccc2c1ccccc1n(C)c2c3)=C4)cc5",
    "COc1ccccc1C/C=C/C3=CC(/C=C/Cc2ccccc2OC)=[O+][B-](F)(F)O3",
    "CCCCCC(CC)c5ccc(c4ccc(C/C=C/C3=CC(/C=C/Cc2ccc(c1ccc(C(CC)CCCCC)s1)s2)=[O+][B-](F)(F)O3)s4)s5"
)

# Defining the molecule names and HOMO-LUMO Gap
molecule_names = ['2-ADMeO3', '3-MR83a', 'AD-10', 'AD-1013', 'AD-1022', 'AD-11', 'AD-12', 'AD-13', 'AD-13-DMF', 'AD-14-Moore', 'AD-15', 'AD-15-DMF', 'AD-16-DMF', 'AD-18', 'AD-24', 'AD-25', 'AD-3', 'AD-35', 'AD-4', 'AD-48', 'AD-5', 'AD-6', 'AD-7', 'AD-8', 'AD-9', 'YD-30']
homo_lumo_gap = [3.077, 3.072, 3.259, 2.625, 2.938, 2.946, 3.191, 3.226, 3.228, 2.811, 2.971, 2.813, 3.231, 2.735, 2.878, 2.686, 3.215, 2.77, 3.001, 2.702, 2.97, 2.89, 2.859, 2.97, 3.137, 2.525]

molecules = [Chem.MolFromSmiles(smiles) for smiles in curcumin_variants]
mws = [round(Descriptors.MolWt(mol),3) for mol in molecules]
logp = [Descriptors.MolLogP(mol) for mol in molecules]

# Create the initial DataFrame
data = {
    'Molecule': molecule_names,
    'Molecular Weight': mws,
    'LogP': logp,
    'Homo-Lumo Gap (eV)': homo_lumo_gap,
    'Smiles': curcumin_variants
}
curcumin_df = pd.DataFrame(data)

# Function to generate Morgan fingerprints safely
def generate_morgan_fingerprint_safe(smiles):
    """Generate Morgan fingerprint and handle errors gracefully."""
    try:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            return list(AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=2048))
    except Exception:
        return None
    return None

# apply morgan fingerprint to the curcumin_df dataframe
curcumin_df['Morgan_Fingerprints'] = curcumin_df['Smiles'].apply(generate_morgan_fingerprint_safe)
curcumin_df = curcumin_df[curcumin_df['Morgan_Fingerprints'].notnull()].reset_index(drop=True)
morgan_df = pd.DataFrame(curcumin_df['Morgan_Fingerprints'].tolist(), columns=[f'morgan_{i}' for i in range(2048)])

curcumin_df = pd.concat([curcumin_df.drop(columns=['Morgan_Fingerprints']), morgan_df], axis=1)

# Harvard OPV dataset import
data = pd.read_csv('https://raw.githubusercontent.com/AjStephan/havard-smile-opv/main/Non-fullerene%20small-molecules%20acceptors.csv')
opv_df = data.drop(columns=[
    'index', 'inchikey', 'HOMO_calc', 'LUMO_calc', 'LUMO_calib', 'LUMO_calib_stds',
    'HOMO_calib', 'HOMO_calib_stds','GAP_calc', 'molW', 'PCE_calc', 'Voc_calc', 'Jsc_calc',
    'FF_calc', 'EQE_calc', 'PCE_calib', 'Voc_calib', 'Jsc_calib', 'FF_calib',
    'EQE_calib', 'PCE_cdiff', 'PCE_calib_plus'], axis=1)
# Out:
# CPU times: total: 250 ms
# Wall time: 11.6 s

# %%
curcumin_variants_dict = {
    "curcumin_variant00": "COc3cc(OC)c(C/C=C/C2=CC(/C=C/Cc1c(OC)cc(OC)cc1OC)=[O+][B-](F)(F)O2)c(OC)c3",
    "curcumin_variant01": "COc3ccc(C/C=C/C2=[O+][B-](F)(F)OC(/C=C/Cc1c(OC)cc(OC)cc1OC)=C2)cc3",
    "curcumin_variant02": "COc3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(OC)cc1OC)=[O+][B-](F)(F)O2)c(OC)c3",
    "curcumin_variant03": "COc5ccc(C/C=C/C4=[O+][B-](F)(F)OC(/C=C/Cc2c1ccccc1cc3ccccc23)=C4)cc5",
    "curcumin_variant04": "COc3ccc(OC)c(C/C=C/C2=CC(/C=C/Cc1cc(OC)ccc1OC)=[O+][B-](F)(F)O2)c3",
    "curcumin_variant05": "COc3cc(C/C=C/C2=CC(/C=C/Cc1ccc(O)c(OC)c1)=[O+][B-](F)(F)O2)ccc3O",
    "curcumin_variant06": "F[B-]3(F)OC(/C=C/Cc1ccc(Br)cc1)=CC(/C=C/Cc2ccc(Br)cc2)=[O+]3",
    "curcumin_variant07": "C=C(OC)c3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(C(=C)OC)cc1)=[O+][B-](F)(F)O2)cc3",
    "curcumin_variant08": "C=C(OC)c3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(C(=C)OC)cc1)=[O+][B-](F)(F)O2)cc3",
    "curcumin_variant09": "CN(C)c3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(N(C)C)cc1)=[O+][B-](F)(F)O2)cc3",
    "curcumin_variant10": "CCCOc1cc(N(CC)CC)ccc1C/C=C/C3=CC(/C=C/Cc2ccc(N(CC)CC)cc2OCCC)=[O+][B-](F)(F)O3",
    "curcumin_variant11": "CCCOc1cc(N(CC)CC)ccc1C/C=C/C3=CC(/C=C/Cc2ccc(N(CC)CC)cc2OCCC)=[O+][B-](F)(F)O3",
    "curcumin_variant12": "N#Cc3ccc(C/C=C/C2=[O+][B-](F)(F)OC(/C=C/Cc1ccccc1)=C2)cc3",
    "curcumin_variant13": "COc6ccc(C/C=C/C5=CC(/C=C/Cc1cc2ccc3cccc4ccc(c1)c2c34)=[O+][B-](F)(F)O5)cc6",
    "curcumin_variant14": "COc4ccc(C/C=C/C3=CC(/C=C/Cc1ccc(OC)c2ccccc12)=[O+][B-](F)(F)O3)c5ccccc45",
    "curcumin_variant15": "CN(C)c4ccc(C/C=C/C3=CC(/C=C/Cc1ccc(N(C)C)c2ccccc12)=[O+][B-](F)(F)O3)c5ccccc45",
    "curcumin_variant16": "N#Cc3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(C#N)cc1)=[O+][B-](F)(F)O2)cc3",
    "curcumin_variant17": "CCCCN(CCCC)c3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(N(CCCC)CCCC)cc1)=[O+][B-](F)(F)O2)cc3",
    "curcumin_variant18": "COc3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(C#N)cc1)=[O+][B-](F)(F)O2)cc3",
    "curcumin_variant19": "CN5/C(=C\C\C=C\C3=CC(/C=C/C/C=C/2N(C)c1ccccc1C2(C)C)=[O+][B-](F)(F)O3)C(C)(C)c4ccccc45",
    "curcumin_variant20": "COc3ccc(C/C=C/C2=[O+][B-](F)(F)OC(/C=C/Cc1ccc(SC)cc1)=C2)cc3",
    "curcumin_variant21": "CSc3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(SC)cc1)=[O+][B-](F)(F)O2)cc3",
    "curcumin_variant22": "COc3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(N(C)C)cc1)=[O+][B-](F)(F)O2)cc3",
    "curcumin_variant23": "COc5ccc(C/C=C/C4=[O+][B-](F)(F)OC(/C=C/Cc3ccc2c1ccccc1n(C)c2c3)=C4)cc5",
    "curcumin_variant24": "COc1ccccc1C/C=C/C3=CC(/C=C/Cc2ccccc2OC)=[O+][B-](F)(F)O3",
    "curcumin_variant25": "CCCCCC(CC)c5ccc(c4ccc(C/C=C/C3=CC(/C=C/Cc2ccc(c1ccc(C(CC)CCCCC)s1)s2)=[O+][B-](F)(F)O3)s4)s5"
}

# %%
# import pandas as pd
# from rdkit import Chem
# from rdkit.Chem import AllChem, DataStructs

# # Dictionary to hold the dataframes
# similarity_dfs = {}

# # Function to calculate similarity
# def calculate_similarity(fp1, fp2, metric="kulczynski"):
#     if metric == "kulczynski":
#         return DataStructs.KulczynskiSimilarity(fp1, fp2)
#     else:
#         raise ValueError(f"Unknown similarity metric: {metric}")

# # Function to generate Morgan fingerprints safely
# def generate_morgan_fingerprint_safe(smiles):
#     mol = Chem.MolFromSmiles(smiles)
#     if mol is not None:
#         return list(AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=2048))
#     else:
#         return None

# # Quantile range setup
# quantiles = [0.24, 0.30, 0.36, 0.42]

# print("Processing similarity dataframes...")

# # Loop over curcumin variants and create similarity dataframes
# for key, smiles in curcumin_variants_dict.items():
#     specific_mol = Chem.MolFromSmiles(smiles)
#     specific_fp = AllChem.GetMorganFingerprintAsBitVect(specific_mol, 2, nBits=2048)

#     for i, quantile in enumerate(quantiles[:-1]):
#         # Calculate similarity and create a new dataframe with similarity scores
#         opv_df_sim_segment = opv_df.copy()
#         opv_df_sim_segment['mol'] = opv_df_sim_segment['smiles'].apply(Chem.MolFromSmiles)
#         opv_df_sim_segment[f'similarity_{key}_morgan_kulczynski'] = opv_df_sim_segment['mol'].apply(
#             lambda x: calculate_similarity(AllChem.GetMorganFingerprintAsBitVect(x, 2, nBits=2048), specific_fp)
#         )

#         # Filter molecules within the specified quantile range
#         lower_quantile_value = opv_df_sim_segment[f'similarity_{key}_morgan_kulczynski'].quantile(quantile)
#         upper_quantile_value = opv_df_sim_segment[f'similarity_{key}_morgan_kulczynski'].quantile(quantiles[i+1])
#         filtered_df = opv_df_sim_segment[(opv_df_sim_segment[f'similarity_{key}_morgan_kulczynski'] >= lower_quantile_value) &
#                                          (opv_df_sim_segment[f'similarity_{key}_morgan_kulczynski'] < upper_quantile_value)]

#         # Keep only the relevant columns (initial columns + similarity)
#         filtered_df = filtered_df[['smiles', 'mol', 'GAP_calib', f'similarity_{key}_morgan_kulczynski']]

#         # Store the filtered dataframe in the dictionary with appropriate naming
#         similarity_dfs[f'{key}_morgan_kulczynski_q{int(quantile*100)}_to_q{int(quantiles[i+1]*100)}'] = filtered_df

# print("Done processing similarity dataframes.")

# # Dictionary to store DataFrames with Morgan fingerprints
# similarity_dfs_top_quantiles = {}

# print("Processing similarity dataframes with Morgan fingerprints...")

# # Process each dataframe in the similarity_dfs dictionary
# for key, df in similarity_dfs.items():
#     # Generate Morgan fingerprints for the smiles in the dataframe
#     df['Morgan_Fingerprints'] = df['smiles'].apply(generate_morgan_fingerprint_safe)
    
#     # Filter out rows where Morgan fingerprints could not be generated
#     df = df[df['Morgan_Fingerprints'].notnull()].reset_index(drop=True)
    
#     # Convert the list of fingerprints into a DataFrame
#     morgan_df = pd.DataFrame(df['Morgan_Fingerprints'].tolist(), columns=[f'morgan_{i}' for i in range(2048)])
    
#     # Concatenate the original DataFrame with the Morgan fingerprints DataFrame
#     df_mf = pd.concat([df.drop(columns=['Morgan_Fingerprints']), morgan_df], axis=1)
    
#     # Store the final DataFrame in the new dictionary
#     similarity_dfs_top_quantiles[key] = df_mf
    
#     print(f"Done processing {key} dataframe - shape {df_mf.shape}")

# # Unpacking the dictionary to global variables
# for key in similarity_dfs_top_quantiles.keys():
#     globals()[f'similarity_dfs_top_quantiles_{key}'] = similarity_dfs_top_quantiles[key]

# print("Done processing similarity dataframes with Morgan fingerprints.")

# %%
# %%time
from rdkit import Chem
from rdkit.Chem import AllChem, DataStructs

# Dictionary to hold the dataframes
similarity_dfs = {}

# Function to calculate similarity
def calculate_similarity(fp1, fp2, metric="kulczynski"):
    if metric == "kulczynski":
        return DataStructs.KulczynskiSimilarity(fp1, fp2)
    else:
        raise ValueError(f"Unknown similarity metric: {metric}")

print("Processing similarity dataframes...")

# Loop over curcumin variants and create similarity dataframes
for key, smiles in curcumin_variants_dict.items():
    specific_mol = Chem.MolFromSmiles(smiles)
    specific_fp = AllChem.GetMorganFingerprintAsBitVect(specific_mol, 2, nBits=2048)

    # Calculate similarity and create a new dataframe with similarity scores
    opv_df_sim_segment = opv_df.copy()
    opv_df_sim_segment['mol'] = opv_df_sim_segment['smiles'].apply(Chem.MolFromSmiles)
    opv_df_sim_segment[f'similarity_{key}_morgan_kulczynski'] = opv_df_sim_segment['mol'].apply(
        lambda x: calculate_similarity(AllChem.GetMorganFingerprintAsBitVect(x, 2, nBits=2048), specific_fp)
    )

    # Filter top 36% similar molecules
    quantile_value = opv_df_sim_segment[f'similarity_{key}_morgan_kulczynski'].quantile(0.64)
    filtered_df = opv_df_sim_segment[opv_df_sim_segment[f'similarity_{key}_morgan_kulczynski'] >= quantile_value]

    # Keep only the relevant columns (initial columns + similarity)
    filtered_df = filtered_df[['smiles', 'mol', 'GAP_calib', f'similarity_{key}_morgan_kulczynski']]

    # Store the filtered dataframe in the dictionary
    similarity_dfs[f'{key}_morgan_kulczynski'] = filtered_df

print("Done processing similarity dataframes.")

# Dictionary to store DataFrames with Morgan fingerprints
similarity_dfs_top36 = {}

print("Processing similarity dataframes with Morgan fingerprints...")

# Process each dataframe in the similarity_dfs dictionary
for key, df in similarity_dfs.items():
    # Generate Morgan fingerprints for the smiles in the dataframe
    df['Morgan_Fingerprints'] = df['smiles'].apply(generate_morgan_fingerprint_safe)
    
    # Filter out rows where Morgan fingerprints could not be generated
    df = df[df['Morgan_Fingerprints'].notnull()].reset_index(drop=True)
    
    # Convert the list of fingerprints into a DataFrame
    morgan_df = pd.DataFrame(df['Morgan_Fingerprints'].tolist(), columns=[f'morgan_{i}' for i in range(2048)])
    
    # Concatenate the original DataFrame with the Morgan fingerprints DataFrame
    df_mf = pd.concat([df.drop(columns=['Morgan_Fingerprints']), morgan_df], axis=1)
    
    # Store the final DataFrame in the new dictionary
    similarity_dfs_top36[key] = df_mf
    
    print(f"Done processing {key} dataframe - shape {df_mf.shape}")

# Unpacking the dictionary to global variables
for curcumin_variants_dict in similarity_dfs_top36.keys():
    globals()[f'similarity_dfs_top36_{curcumin_variants_dict}'] = similarity_dfs_top36[curcumin_variants_dict]

print("Done processing similarity dataframes with Morgan fingerprints.")
# Out:
# Processing similarity dataframes...
# Done processing similarity dataframes.
# Processing similarity dataframes with Morgan fingerprints...
# Done processing curcumin_variant00_morgan_kulczynski dataframe - shape (18725, 2052)
# Done processing curcumin_variant01_morgan_kulczynski dataframe - shape (18725, 2052)
# Done processing curcumin_variant02_morgan_kulczynski dataframe - shape (18558, 2052)
# Done processing curcumin_variant03_morgan_kulczynski dataframe - shape (18664, 2052)
# Done processing curcumin_variant04_morgan_kulczynski dataframe - shape (18607, 2052)
# Done processing curcumin_variant05_morgan_kulczynski dataframe - shape (18589, 2052)
# Done processing curcumin_variant06_morgan_kulczynski dataframe - shape (18561, 2052)
# Done processing curcumin_variant07_morgan_kulczynski dataframe - shape (18590, 2052)
# Done processing curcumin_variant08_morgan_kulczynski dataframe - shape (18590, 2052)
# Done processing curcumin_variant09_morgan_kulczynski dataframe - shape (18754, 2052)
# Done processing curcumin_variant10_morgan_kulczynski dataframe - shape (18629, 2052)
# Done processing curcumin_variant11_morgan_kulczynski dataframe - shape (18629, 2052)
# Done processing curcumin_variant12_morgan_kulczynski dataframe - shape (18456, 2052)
# Done processing curcumin_variant13_morgan_kulczynski dataframe - shape (18514, 2052)
# Done processing curcumin_variant14_morgan_kulczynski dataframe - shape (18704, 2052)
# Done processing curcumin_variant15_morgan_kulczynski dataframe - shape (18549, 2052)
# Done processing curcumin_variant16_morgan_kulczynski dataframe - shape (18479, 2052)
# Done processing curcumin_variant17_morgan_kulczynski dataframe - shape (18713, 2052)
# Done processing curcumin_variant18_morgan_kulczynski dataframe - shape (18553, 2052)
# Done processing curcumin_variant19_morgan_kulczynski dataframe - shape (18657, 2052)
# Done processing curcumin_variant20_morgan_kulczynski dataframe - shape (18702, 2052)
# Done processing curcumin_variant21_morgan_kulczynski dataframe - shape (18781, 2052)
# Done processing curcumin_variant22_morgan_kulczynski dataframe - shape (18821, 2052)
# Done processing curcumin_variant23_morgan_kulczynski dataframe - shape (18520, 2052)
# Done processing curcumin_variant24_morgan_kulczynski dataframe - shape (18521, 2052)
# Done processing curcumin_variant25_morgan_kulczynski dataframe - shape (18542, 2052)
# Done processing similarity dataframes with Morgan fingerprints.
# CPU times: total: 16min 2s
# Wall time: 16min 27s

# %%
# %%time
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

curcumin_variants_dict = {
    "curcumin_variant00": "COc3cc(OC)c(C/C=C/C2=CC(/C=C/Cc1c(OC)cc(OC)cc1OC)=[O+][B-](F)(F)O2)c(OC)c3",
    "curcumin_variant01": "COc3ccc(C/C=C/C2=[O+][B-](F)(F)OC(/C=C/Cc1c(OC)cc(OC)cc1OC)=C2)cc3",
    "curcumin_variant02": "COc3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(OC)cc1OC)=[O+][B-](F)(F)O2)c(OC)c3",
    "curcumin_variant03": "COc5ccc(C/C=C/C4=[O+][B-](F)(F)OC(/C=C/Cc2c1ccccc1cc3ccccc23)=C4)cc5",
    "curcumin_variant04": "COc3ccc(OC)c(C/C=C/C2=CC(/C=C/Cc1cc(OC)ccc1OC)=[O+][B-](F)(F)O2)c3",
    "curcumin_variant05": "COc3cc(C/C=C/C2=CC(/C=C/Cc1ccc(O)c(OC)c1)=[O+][B-](F)(F)O2)ccc3O",
    "curcumin_variant06": "F[B-]3(F)OC(/C=C/Cc1ccc(Br)cc1)=CC(/C=C/Cc2ccc(Br)cc2)=[O+]3",
    "curcumin_variant07": "C=C(OC)c3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(C(=C)OC)cc1)=[O+][B-](F)(F)O2)cc3",
    "curcumin_variant08": "C=C(OC)c3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(C(=C)OC)cc1)=[O+][B-](F)(F)O2)cc3",
    "curcumin_variant09": "CN(C)c3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(N(C)C)cc1)=[O+][B-](F)(F)O2)cc3",
    "curcumin_variant10": "CCCOc1cc(N(CC)CC)ccc1C/C=C/C3=CC(/C=C/Cc2ccc(N(CC)CC)cc2OCCC)=[O+][B-](F)(F)O3",
    "curcumin_variant11": "CCCOc1cc(N(CC)CC)ccc1C/C=C/C3=CC(/C=C/Cc2ccc(N(CC)CC)cc2OCCC)=[O+][B-](F)(F)O3",
    "curcumin_variant12": "N#Cc3ccc(C/C=C/C2=[O+][B-](F)(F)OC(/C=C/Cc1ccccc1)=C2)cc3",
    "curcumin_variant13": "COc6ccc(C/C=C/C5=CC(/C=C/Cc1cc2ccc3cccc4ccc(c1)c2c34)=[O+][B-](F)(F)O5)cc6",
    "curcumin_variant14": "COc4ccc(C/C=C/C3=CC(/C=C/Cc1ccc(OC)c2ccccc12)=[O+][B-](F)(F)O3)c5ccccc45",
    "curcumin_variant15": "CN(C)c4ccc(C/C=C/C3=CC(/C=C/Cc1ccc(N(C)C)c2ccccc12)=[O+][B-](F)(F)O3)c5ccccc45",
    "curcumin_variant16": "N#Cc3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(C#N)cc1)=[O+][B-](F)(F)O2)cc3",
    "curcumin_variant17": "CCCCN(CCCC)c3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(N(CCCC)CCCC)cc1)=[O+][B-](F)(F)O2)cc3",
    "curcumin_variant18": "COc3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(C#N)cc1)=[O+][B-](F)(F)O2)cc3",
    "curcumin_variant19": "CN5/C(=C\C\C=C\C3=CC(/C=C/C/C=C/2N(C)c1ccccc1C2(C)C)=[O+][B-](F)(F)O3)C(C)(C)c4ccccc45",
    "curcumin_variant20": "COc3ccc(C/C=C/C2=[O+][B-](F)(F)OC(/C=C/Cc1ccc(SC)cc1)=C2)cc3",
    "curcumin_variant21": "CSc3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(SC)cc1)=[O+][B-](F)(F)O2)cc3",
    "curcumin_variant22": "COc3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(N(C)C)cc1)=[O+][B-](F)(F)O2)cc3",
    "curcumin_variant23": "COc5ccc(C/C=C/C4=[O+][B-](F)(F)OC(/C=C/Cc3ccc2c1ccccc1n(C)c2c3)=C4)cc5",
    "curcumin_variant24": "COc1ccccc1C/C=C/C3=CC(/C=C/Cc2ccccc2OC)=[O+][B-](F)(F)O3",
    "curcumin_variant25": "CCCCCC(CC)c5ccc(c4ccc(C/C=C/C3=CC(/C=C/Cc2ccc(c1ccc(C(CC)CCCCC)s1)s2)=[O+][B-](F)(F)O3)s4)s5"
}

# Define the similarity method and curcumin variants
similarity_method = 'morgan_kulczynski'
curcumin_variants = list(curcumin_variants_dict.keys())

# Create a list of tuples for dataframes using the chosen similarity method
dataframes = [
    (f'similarity_dfs_top36_{variant}_{similarity_method}', globals()[f'similarity_dfs_top36_{variant}_{similarity_method}'])
    for variant in curcumin_variants
]

# Define the LightGBM model with the specified parameters
lgb_model = lgb.LGBMRegressor(
    learning_rate=0.1,
    n_estimators=100,
    random_state=123
)

results = []
best_models = {}  # Dictionary to store the best models by variant name

for name, df in dataframes:
    print(f"Processing {name}...")
    X = df.iloc[:, 4:]
    y = df['GAP_calib']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=123)
    lgb_model.fit(X_train, y_train)
    y_pred = lgb_model.predict(X_test)
    
    r2 = r2_score(y_test, y_pred)
    
    # Store the model and its R2 score
    best_models[name] = lgb_model
    results.append({'variant': name, 'r2_score': r2})

    print(f"Done processing {name} with R2 score: {r2:.4f}")

# Convert results to a DataFrame
final_results_top36 = pd.DataFrame(results)

# Display the first few rows of the final results
final_results_top36.head()
# Out:
# Processing similarity_dfs_top36_curcumin_variant00_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.041642 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2390
# [LightGBM] [Info] Number of data points in the train set: 14043, number of used features: 1195
# [LightGBM] [Info] Start training from score 2.772994
# Done processing similarity_dfs_top36_curcumin_variant00_morgan_kulczynski with R2 score: 0.8947
# Processing similarity_dfs_top36_curcumin_variant01_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.032948 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2378
# [LightGBM] [Info] Number of data points in the train set: 14043, number of used features: 1189
# [LightGBM] [Info] Start training from score 2.806651
# Done processing similarity_dfs_top36_curcumin_variant01_morgan_kulczynski with R2 score: 0.8911
# Processing similarity_dfs_top36_curcumin_variant02_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.030431 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2370
# [LightGBM] [Info] Number of data points in the train set: 13918, number of used features: 1185
# [LightGBM] [Info] Start training from score 2.769318
# Done processing similarity_dfs_top36_curcumin_variant02_morgan_kulczynski with R2 score: 0.8868
# Processing similarity_dfs_top36_curcumin_variant03_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.034628 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2392
# [LightGBM] [Info] Number of data points in the train set: 13998, number of used features: 1196
# [LightGBM] [Info] Start training from score 2.769586
# Done processing similarity_dfs_top36_curcumin_variant03_morgan_kulczynski with R2 score: 0.8857
# Processing similarity_dfs_top36_curcumin_variant04_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.029822 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2412
# [LightGBM] [Info] Number of data points in the train set: 13955, number of used features: 1206
# [LightGBM] [Info] Start training from score 2.778826
# Done processing similarity_dfs_top36_curcumin_variant04_morgan_kulczynski with R2 score: 0.8805
# Processing similarity_dfs_top36_curcumin_variant05_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.036799 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2416
# [LightGBM] [Info] Number of data points in the train set: 13941, number of used features: 1208
# [LightGBM] [Info] Start training from score 2.783203
# Done processing similarity_dfs_top36_curcumin_variant05_morgan_kulczynski with R2 score: 0.8838
# Processing similarity_dfs_top36_curcumin_variant06_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.037918 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2456
# [LightGBM] [Info] Number of data points in the train set: 13920, number of used features: 1228
# [LightGBM] [Info] Start training from score 2.865532
# Done processing similarity_dfs_top36_curcumin_variant06_morgan_kulczynski with R2 score: 0.8681
# Processing similarity_dfs_top36_curcumin_variant07_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.036820 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2380
# [LightGBM] [Info] Number of data points in the train set: 13942, number of used features: 1190
# [LightGBM] [Info] Start training from score 2.816426
# Done processing similarity_dfs_top36_curcumin_variant07_morgan_kulczynski with R2 score: 0.8879
# Processing similarity_dfs_top36_curcumin_variant08_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031090 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2380
# [LightGBM] [Info] Number of data points in the train set: 13942, number of used features: 1190
# [LightGBM] [Info] Start training from score 2.816426
# Done processing similarity_dfs_top36_curcumin_variant08_morgan_kulczynski with R2 score: 0.8879
# Processing similarity_dfs_top36_curcumin_variant09_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031800 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2404
# [LightGBM] [Info] Number of data points in the train set: 14065, number of used features: 1202
# [LightGBM] [Info] Start training from score 2.783090
# Done processing similarity_dfs_top36_curcumin_variant09_morgan_kulczynski with R2 score: 0.8855
# Processing similarity_dfs_top36_curcumin_variant10_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.048523 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2330
# [LightGBM] [Info] Number of data points in the train set: 13971, number of used features: 1165
# [LightGBM] [Info] Start training from score 2.816484
# Done processing similarity_dfs_top36_curcumin_variant10_morgan_kulczynski with R2 score: 0.8798
# Processing similarity_dfs_top36_curcumin_variant11_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.034407 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2330
# [LightGBM] [Info] Number of data points in the train set: 13971, number of used features: 1165
# [LightGBM] [Info] Start training from score 2.816484
# Done processing similarity_dfs_top36_curcumin_variant11_morgan_kulczynski with R2 score: 0.8798
# Processing similarity_dfs_top36_curcumin_variant12_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.037026 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2540
# [LightGBM] [Info] Number of data points in the train set: 13842, number of used features: 1270
# [LightGBM] [Info] Start training from score 2.841669
# Done processing similarity_dfs_top36_curcumin_variant12_morgan_kulczynski with R2 score: 0.8567
# Processing similarity_dfs_top36_curcumin_variant13_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.033038 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2382
# [LightGBM] [Info] Number of data points in the train set: 13885, number of used features: 1191
# [LightGBM] [Info] Start training from score 2.771359
# Done processing similarity_dfs_top36_curcumin_variant13_morgan_kulczynski with R2 score: 0.8820
# Processing similarity_dfs_top36_curcumin_variant14_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.030347 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2432
# [LightGBM] [Info] Number of data points in the train set: 14028, number of used features: 1216
# [LightGBM] [Info] Start training from score 2.760936
# Done processing similarity_dfs_top36_curcumin_variant14_morgan_kulczynski with R2 score: 0.8776
# Processing similarity_dfs_top36_curcumin_variant15_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.037525 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2418
# [LightGBM] [Info] Number of data points in the train set: 13911, number of used features: 1209
# [LightGBM] [Info] Start training from score 2.780956
# Done processing similarity_dfs_top36_curcumin_variant15_morgan_kulczynski with R2 score: 0.8744
# Processing similarity_dfs_top36_curcumin_variant16_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.051505 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2522
# [LightGBM] [Info] Number of data points in the train set: 13859, number of used features: 1261
# [LightGBM] [Info] Start training from score 2.833025
# Done processing similarity_dfs_top36_curcumin_variant16_morgan_kulczynski with R2 score: 0.8851
# Processing similarity_dfs_top36_curcumin_variant17_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.032849 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2386
# [LightGBM] [Info] Number of data points in the train set: 14034, number of used features: 1193
# [LightGBM] [Info] Start training from score 2.782199
# Done processing similarity_dfs_top36_curcumin_variant17_morgan_kulczynski with R2 score: 0.8779
# Processing similarity_dfs_top36_curcumin_variant18_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.037253 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2524
# [LightGBM] [Info] Number of data points in the train set: 13914, number of used features: 1262
# [LightGBM] [Info] Start training from score 2.808016
# Done processing similarity_dfs_top36_curcumin_variant18_morgan_kulczynski with R2 score: 0.8676
# Processing similarity_dfs_top36_curcumin_variant19_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.047018 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2322
# [LightGBM] [Info] Number of data points in the train set: 13992, number of used features: 1161
# [LightGBM] [Info] Start training from score 2.590596
# Done processing similarity_dfs_top36_curcumin_variant19_morgan_kulczynski with R2 score: 0.8845
# Processing similarity_dfs_top36_curcumin_variant20_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.033960 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2392
# [LightGBM] [Info] Number of data points in the train set: 14026, number of used features: 1196
# [LightGBM] [Info] Start training from score 2.785668
# Done processing similarity_dfs_top36_curcumin_variant20_morgan_kulczynski with R2 score: 0.8796
# Processing similarity_dfs_top36_curcumin_variant21_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.035043 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2390
# [LightGBM] [Info] Number of data points in the train set: 14085, number of used features: 1195
# [LightGBM] [Info] Start training from score 2.757654
# Done processing similarity_dfs_top36_curcumin_variant21_morgan_kulczynski with R2 score: 0.8801
# Processing similarity_dfs_top36_curcumin_variant22_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.051300 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2428
# [LightGBM] [Info] Number of data points in the train set: 14115, number of used features: 1214
# [LightGBM] [Info] Start training from score 2.810341
# Done processing similarity_dfs_top36_curcumin_variant22_morgan_kulczynski with R2 score: 0.8833
# Processing similarity_dfs_top36_curcumin_variant23_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.034559 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2380
# [LightGBM] [Info] Number of data points in the train set: 13890, number of used features: 1190
# [LightGBM] [Info] Start training from score 2.660593
# Done processing similarity_dfs_top36_curcumin_variant23_morgan_kulczynski with R2 score: 0.8812
# Processing similarity_dfs_top36_curcumin_variant24_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.032681 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2426
# [LightGBM] [Info] Number of data points in the train set: 13890, number of used features: 1213
# [LightGBM] [Info] Start training from score 2.763041
# Done processing similarity_dfs_top36_curcumin_variant24_morgan_kulczynski with R2 score: 0.8707
# Processing similarity_dfs_top36_curcumin_variant25_morgan_kulczynski...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.034312 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2452
# [LightGBM] [Info] Number of data points in the train set: 13906, number of used features: 1226
# [LightGBM] [Info] Start training from score 2.766900
# Done processing similarity_dfs_top36_curcumin_variant25_morgan_kulczynski with R2 score: 0.8708
# CPU times: total: 1min 36s
# Wall time: 42.9 s
#                                              variant  r2_score
# 0  similarity_dfs_top36_curcumin_variant00_morgan...  0.894683
# 1  similarity_dfs_top36_curcumin_variant01_morgan...  0.891109
# 2  similarity_dfs_top36_curcumin_variant02_morgan...  0.886815
# 3  similarity_dfs_top36_curcumin_variant03_morgan...  0.885748
# 4  similarity_dfs_top36_curcumin_variant04_morgan...  0.880483

# %%
x = curcumin_df.iloc[:, 5:]

for model_key, model in best_models.items():
    # Extract the variant number from the model key
    variant_number = model_key.split('_')[4][-2:]
    
    # Predict the energy gap for all molecules in curcumin_df
    predictions = model.predict(x)
    
    # Create a new column name based on the variant number
    prediction_column_name = f"Homo-Lumo Gap (eV) Prediction - Variant {variant_number}"
    
    # Add the predictions as a new column in the curcumin_df
    curcumin_df[prediction_column_name] = predictions

curcumin_df
# Out:
#        Molecule  Molecular Weight      LogP  Homo-Lumo Gap (eV)  \
# 0      2-ADMeO3           532.345   5.02930               3.077
# 1       3-MR83a           472.293   5.01210               3.072
# 2         AD-10           472.293   5.01210               3.259
# 3       AD-1013           482.335   7.29270               2.625
# 4       AD-1022           472.293   5.01210               2.938
# 5         AD-11           444.239   4.40610               2.946
# 6         AD-12           509.981   6.50270               3.191
# 7         AD-13           464.317   6.21190               3.226
# 8     AD-13-DMF           464.317   6.21190               3.228
# 9   AD-14-Moore           438.327   5.10970               2.811
# 10        AD-15           610.595   8.24770               2.971
# 11    AD-15-DMF           610.595   8.24770               2.813
# 12    AD-16-DMF           377.199   4.84938               3.231
# 13        AD-18           506.357   7.88370               2.735
# 14        AD-24           512.361   7.30130               2.878
# 15        AD-25           538.447   7.41610               2.686
# 16         AD-3           402.209   4.72106               3.215
# 17        AD-35           606.651   9.79090               2.770
# 18         AD-4           407.225   4.85798               3.001
# 19        AD-48           542.479   7.89550               2.702
# 20         AD-5           428.309   5.70820               2.970
# 21         AD-6           444.377   6.42150               2.890
# 22         AD-7           425.284   5.05230               2.859
# 23         AD-8           485.339   6.63120               2.970
# 24         AD-9           412.241   4.99490               3.137
# 25        YD-30           752.933  14.70550               2.525
#
#                                                Smiles  morgan_0  morgan_1  \
# 0   COc3cc(OC)c(C/C=C/C2=CC(/C=C/Cc1c(OC)cc(OC)cc1...         0         0
# 1   COc3ccc(C/C=C/C2=[O+][B-](F)(F)OC(/C=C/Cc1c(OC...         0         0
# 2   COc3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(OC)cc1OC)=[O+]...         0         0
# 3   COc5ccc(C/C=C/C4=[O+][B-](F)(F)OC(/C=C/Cc2c1cc...         0         0
# 4   COc3ccc(OC)c(C/C=C/C2=CC(/C=C/Cc1cc(OC)ccc1OC)...         0         0
# 5   COc3cc(C/C=C/C2=CC(/C=C/Cc1ccc(O)c(OC)c1)=[O+]...         0         0
# 6   F[B-]3(F)OC(/C=C/Cc1ccc(Br)cc1)=CC(/C=C/Cc2ccc...         0         0
# 7   C=C(OC)c3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(C(=C)OC)c...         0         0
# 8   C=C(OC)c3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(C(=C)OC)c...         0         0
# 9   CN(C)c3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(N(C)C)cc1)=...         0         0
# 10  CCCOc1cc(N(CC)CC)ccc1C/C=C/C3=CC(/C=C/Cc2ccc(N...         0         0
# 11  CCCOc1cc(N(CC)CC)ccc1C/C=C/C3=CC(/C=C/Cc2ccc(N...         0         0
# 12  N#Cc3ccc(C/C=C/C2=[O+][B-](F)(F)OC(/C=C/Cc1ccc...         0         0
# 13  COc6ccc(C/C=C/C5=CC(/C=C/Cc1cc2ccc3cccc4ccc(c1...         0         0
# 14  COc4ccc(C/C=C/C3=CC(/C=C/Cc1ccc(OC)c2ccccc12)=...         0         0
# 15  CN(C)c4ccc(C/C=C/C3=CC(/C=C/Cc1ccc(N(C)C)c2ccc...         0         0
# 16  N#Cc3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(C#N)cc1)=[O+]...         0         0
# 17  CCCCN(CCCC)c3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(N(CCC...         0         0
# 18  COc3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(C#N)cc1)=[O+][...         0         0
# 19  CN5/C(=C\C\C=C\C3=CC(/C=C/C/C=C/2N(C)c1ccccc1C...         0         0
# 20  COc3ccc(C/C=C/C2=[O+][B-](F)(F)OC(/C=C/Cc1ccc(...         0         0
# 21  CSc3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(SC)cc1)=[O+][B...         0         0
# 22  COc3ccc(C/C=C/C2=CC(/C=C/Cc1ccc(N(C)C)cc1)=[O+...         0         0
# 23  COc5ccc(C/C=C/C4=[O+][B-](F)(F)OC(/C=C/Cc3ccc2...         0         0
# 24  COc1ccccc1C/C=C/C3=CC(/C=C/Cc2ccccc2OC)=[O+][B...         0         0
# 25  CCCCCC(CC)c5ccc(c4ccc(C/C=C/C3=CC(/C=C/Cc2ccc(...         0         1
#
#     morgan_2  morgan_3  morgan_4  ...  \
# 0          0         0         0  ...
# 1          0         0         0  ...
# 2          0         0         0  ...
# 3          0         0         0  ...
# 4          0         0         1  ...
# 5          0         0         0  ...
# 6          0         0         0  ...
# 7          0         0         0  ...
# 8          0         0         0  ...
# 9          0         0         0  ...
# 10         0         0         0  ...
# 11         0         0         0  ...
# 12         0         0         0  ...
# 13         0         0         0  ...
# 14         0         0         0  ...
# 15         0         0         0  ...
# 16         0         0         0  ...
# 17         0         0         0  ...
# 18         0         0         0  ...
# 19         0         0         0  ...
# 20         0         0         0  ...
# 21         0         0         0  ...
# 22         0         0         0  ...
# 23         0         0         0  ...
# 24         0         0         0  ...
# 25         0         0         0  ...
#
#     Homo-Lumo Gap (eV) Prediction - Variant 16  \
# 0                                     3.162326
# 1                                     3.159680
# 2                                     2.921301
# 3                                     3.023356
# 4                                     2.930718
# 5                                     3.035397
# 6                                     3.250347
# 7                                     3.062199
# 8                                     3.062199
# 9                                     3.230558
# 10                                    2.616156
# 11                                    2.616156
# 12                                    3.301899
# 13                                    3.102544
# 14                                    2.907474
# 15                                    2.911803
# 16                                    3.273033
# 17                                    3.201634
# 18                                    3.195591
# 19                                    2.469793
# 20                                    3.209769
# 21                                    3.209769
# 22                                    3.230558
# 23                                    2.652913
# 24                                    2.929349
# 25                                    3.105058
#
#     Homo-Lumo Gap (eV) Prediction - Variant 17  \
# 0                                     3.162326
# 1                                     3.159680
# 2                                     2.921301
# 3                                     3.023356
# 4                                     2.930718
# 5                                     3.035397
# 6                                     3.250347
# 7                                     3.062199
# 8                                     3.062199
# 9                                     3.230558
# 10                                    2.616156
# 11                                    2.616156
# 12                                    3.301899
# 13                                    3.102544
# 14                                    2.907474
# 15                                    2.911803
# 16                                    3.273033
# 17                                    3.201634
# 18                                    3.195591
# 19                                    2.469793
# 20                                    3.209769
# 21                                    3.209769
# 22                                    3.230558
# 23                                    2.652913
# 24                                    2.929349
# 25                                    3.105058
#
#     Homo-Lumo Gap (eV) Prediction - Variant 18  \
# 0                                     3.162326
# 1                                     3.159680
# 2                                     2.921301
# 3                                     3.023356
# 4                                     2.930718
# 5                                     3.035397
# 6                                     3.250347
# 7                                     3.062199
# 8                                     3.062199
# 9                                     3.230558
# 10                                    2.616156
# 11                                    2.616156
# 12                                    3.301899
# 13                                    3.102544
# 14                                    2.907474
# 15                                    2.911803
# 16                                    3.273033
# 17                                    3.201634
# 18                                    3.195591
# 19                                    2.469793
# 20                                    3.209769
# 21                                    3.209769
# 22                                    3.230558
# 23                                    2.652913
# 24                                    2.929349
# 25                                    3.105058
#
#     Homo-Lumo Gap (eV) Prediction - Variant 19  \
# 0                                     3.162326
# 1                                     3.159680
# 2                                     2.921301
# 3                                     3.023356
# 4                                     2.930718
# 5                                     3.035397
# 6                                     3.250347
# 7                                     3.062199
# 8                                     3.062199
# 9                                     3.230558
# 10                                    2.616156
# 11                                    2.616156
# 12                                    3.301899
# 13                                    3.102544
# 14                                    2.907474
# 15                                    2.911803
# 16                                    3.273033
# 17                                    3.201634
# 18                                    3.195591
# 19                                    2.469793
# 20                                    3.209769
# 21                                    3.209769
# 22                                    3.230558
# 23                                    2.652913
# 24                                    2.929349
# 25                                    3.105058
#
#     Homo-Lumo Gap (eV) Prediction - Variant 20  \
# 0                                     3.162326
# 1                                     3.159680
# 2                                     2.921301
# 3                                     3.023356
# 4                                     2.930718
# 5                                     3.035397
# 6                                     3.250347
# 7                                     3.062199
# 8                                     3.062199
# 9                                     3.230558
# 10                                    2.616156
# 11                                    2.616156
# 12                                    3.301899
# 13                                    3.102544
# 14                                    2.907474
# 15                                    2.911803
# 16                                    3.273033
# 17                                    3.201634
# 18                                    3.195591
# 19                                    2.469793
# 20                                    3.209769
# 21                                    3.209769
# 22                                    3.230558
# 23                                    2.652913
# 24                                    2.929349
# 25                                    3.105058
#
#     Homo-Lumo Gap (eV) Prediction - Variant 21  \
# 0                                     3.162326
# 1                                     3.159680
# 2                                     2.921301
# 3                                     3.023356
# 4                                     2.930718
# 5                                     3.035397
# 6                                     3.250347
# 7                                     3.062199
# 8                                     3.062199
# 9                                     3.230558
# 10                                    2.616156
# 11                                    2.616156
# 12                                    3.301899
# 13                                    3.102544
# 14                                    2.907474
# 15                                    2.911803
# 16                                    3.273033
# 17                                    3.201634
# 18                                    3.195591
# 19                                    2.469793
# 20                                    3.209769
# 21                                    3.209769
# 22                                    3.230558
# 23                                    2.652913
# 24                                    2.929349
# 25                                    3.105058
#
#     Homo-Lumo Gap (eV) Prediction - Variant 22  \
# 0                                     3.162326
# 1                                     3.159680
# 2                                     2.921301
# 3                                     3.023356
# 4                                     2.930718
# 5                                     3.035397
# 6                                     3.250347
# 7                                     3.062199
# 8                                     3.062199
# 9                                     3.230558
# 10                                    2.616156
# 11                                    2.616156
# 12                                    3.301899
# 13                                    3.102544
# 14                                    2.907474
# 15                                    2.911803
# 16                                    3.273033
# 17                                    3.201634
# 18                                    3.195591
# 19                                    2.469793
# 20                                    3.209769
# 21                                    3.209769
# 22                                    3.230558
# 23                                    2.652913
# 24                                    2.929349
# 25                                    3.105058
#
#     Homo-Lumo Gap (eV) Prediction - Variant 23  \
# 0                                     3.162326
# 1                                     3.159680
# 2                                     2.921301
# 3                                     3.023356
# 4                                     2.930718
# 5                                     3.035397
# 6                                     3.250347
# 7                                     3.062199
# 8                                     3.062199
# 9                                     3.230558
# 10                                    2.616156
# 11                                    2.616156
# 12                                    3.301899
# 13                                    3.102544
# 14                                    2.907474
# 15                                    2.911803
# 16                                    3.273033
# 17                                    3.201634
# 18                                    3.195591
# 19                                    2.469793
# 20                                    3.209769
# 21                                    3.209769
# 22                                    3.230558
# 23                                    2.652913
# 24                                    2.929349
# 25                                    3.105058
#
#     Homo-Lumo Gap (eV) Prediction - Variant 24  \
# 0                                     3.162326
# 1                                     3.159680
# 2                                     2.921301
# 3                                     3.023356
# 4                                     2.930718
# 5                                     3.035397
# 6                                     3.250347
# 7                                     3.062199
# 8                                     3.062199
# 9                                     3.230558
# 10                                    2.616156
# 11                                    2.616156
# 12                                    3.301899
# 13                                    3.102544
# 14                                    2.907474
# 15                                    2.911803
# 16                                    3.273033
# 17                                    3.201634
# 18                                    3.195591
# 19                                    2.469793
# 20                                    3.209769
# 21                                    3.209769
# 22                                    3.230558
# 23                                    2.652913
# 24                                    2.929349
# 25                                    3.105058
#
#     Homo-Lumo Gap (eV) Prediction - Variant 25
# 0                                     3.162326
# 1                                     3.159680
# 2                                     2.921301
# 3                                     3.023356
# 4                                     2.930718
# 5                                     3.035397
# 6                                     3.250347
# 7                                     3.062199
# 8                                     3.062199
# 9                                     3.230558
# 10                                    2.616156
# 11                                    2.616156
# 12                                    3.301899
# 13                                    3.102544
# 14                                    2.907474
# 15                                    2.911803
# 16                                    3.273033
# 17                                    3.201634
# 18                                    3.195591
# 19                                    2.469793
# 20                                    3.209769
# 21                                    3.209769
# 22                                    3.230558
# 23                                    2.652913
# 24                                    2.929349
# 25                                    3.105058
#
# [26 rows x 2079 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

for variant in range(26):
    # Generate the column name based on the variant number
    prediction_column = f'Homo-Lumo Gap (eV) Prediction - Variant {variant:02d}'
    
    # Calculate the absolute variance for this variant
    curcumin_df['absolute_variance'] = (curcumin_df['Homo-Lumo Gap (eV)'] - curcumin_df[prediction_column]).abs()

    # Calculate the R² score for this variant
    r2 = r2_score(curcumin_df['Homo-Lumo Gap (eV)'], curcumin_df[prediction_column])
    print(f"Overall R² score for {prediction_column}: {r2:.4f}")

    # Plotting the actual vs predicted energy gaps for this variant
    fig, ax1 = plt.subplots(figsize=(14, 7))

    # Plot the actual values
    ax1.plot(curcumin_df['Molecule'], curcumin_df['Homo-Lumo Gap (eV)'], marker='o', label='Actual HOMO-LUMO Gap (eV)', color='blue')

    # Plot the predicted values
    ax1.plot(curcumin_df['Molecule'], curcumin_df[prediction_column], marker='x', linestyle='--', label=f'Predicted HOMO-LUMO Gap (eV) - Variant {variant:02d}', color='green')

    # Plot the absolute variance as a dotted line
    ax1.plot(curcumin_df['Molecule'], curcumin_df['absolute_variance'], marker='d', linestyle=':', label='Absolute Variance', color='orange')

    # Set labels for the y-axis and the range
    ax1.set_xlabel('Molecule Names')
    ax1.set_ylabel('Energy Gap (eV)')
    ax1.set_ylim([0, 4])  # Y-axis range from 0 to 4
    ax1.tick_params(axis='y')
    ax1.legend(loc='upper right')

    # Customize the plot
    plt.title(f'Comparison of Actual vs Predicted HOMO-LUMO Gap (eV) and Absolute Variance - Variant {variant:02d}')
    plt.xticks(rotation=90)  # Rotate x-axis labels vertically
    plt.tight_layout()

    # Show the plot
    plt.show()
# Out:
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 00: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 01: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 02: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 03: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 04: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 05: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 06: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 07: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 08: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 09: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 10: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 11: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 12: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 13: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 14: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 15: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 16: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 17: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 18: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 19: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 20: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 21: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 22: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 23: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 24: -0.8059
# Overall R² score for Homo-Lumo Gap (eV) Prediction - Variant 25: -0.8059

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming curcumin_df already has a 'Homo-Lumo Gap (eV) Predicted' column from the previous steps

# Sort curcumin_df by 'Homo-Lumo Gap (eV)' in descending order and reset the index
curcumin_df = curcumin_df.sort_values(by='Homo-Lumo Gap (eV)', ascending=False).reset_index(drop=True)

# Calculate the absolute variance between 'Homo-Lumo Gap (eV)' and 'Homo-Lumo Gap (eV) Predicted'
curcumin_df['absolute_variance'] = (curcumin_df['Homo-Lumo Gap (eV)'] - curcumin_df['Homo-Lumo Gap (eV) Predicted']).abs()

# Plotting the actual vs predicted energy gaps
fig, ax1 = plt.subplots(figsize=(14, 7))

# Plot the actual values
ax1.plot(curcumin_df['Molecule'], curcumin_df['Homo-Lumo Gap (eV)'], marker='o', label='Actual HOMO-LUMO Gap (eV)', color='blue')

# Plot the predicted values
ax1.plot(curcumin_df['Molecule'], curcumin_df['Homo-Lumo Gap (eV) Predicted'], marker='x', linestyle='--', label='Predicted HOMO-LUMO Gap (eV)', color='green')

# Plot the absolute variance as a dotted line
ax1.plot(curcumin_df['Molecule'], curcumin_df['absolute_variance'], marker='d', linestyle=':', label='Absolute Variance', color='orange')

# Set labels for the y-axis and the range
ax1.set_xlabel('Molecule Names')
ax1.set_ylabel('Energy Gap (eV)')
ax1.set_ylim([0, 4])  # Y-axis range from 0 to 4
ax1.tick_params(axis='y')
ax1.legend(loc='upper right')

# Customize the plot
plt.title('Comparison of Actual vs Predicted HOMO-LUMO Gap (eV) and Absolute Variance')
plt.xticks(rotation=90)  # Rotate x-axis labels vertically
plt.tight_layout()

# Show the plot
plt.show()

# %%
overall_r2 = r2_score(curcumin_df['Homo-Lumo Gap (eV)'], curcumin_df['Homo-Lumo Gap (eV) Predicted'])
print(f"Overall R² score: {overall_r2:.4f}")
# Out:
# Overall R² score: -0.8059
