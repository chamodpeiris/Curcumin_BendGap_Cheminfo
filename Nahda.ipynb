# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

path = r"https://raw.githubusercontent.com/nahdarantung/Thesis/refs/heads/main/All%20Data%20with%20MnO2%20pour%20density%20and%20surface%20area%20(paper).csv"
df = pd.read_csv(path)

X = df.drop(columns=['Max Current', 'Capacity'])
y = df['Max Current']

df = pd.concat([X, y], axis=1)

from pycaret.regression import *

exp = setup(data = df, target = 'Max Current', session_id=123, verbose=False)
model = compare_models(exclude=['catboost'])
evaluate_model(model)
# Out:
# <style type="text/css">
# #T_a7cb3 th {
#   text-align: left;
# }
# #T_a7cb3_row0_col0, #T_a7cb3_row1_col0, #T_a7cb3_row1_col1, #T_a7cb3_row1_col2, #T_a7cb3_row1_col3, #T_a7cb3_row1_col4, #T_a7cb3_row1_col5, #T_a7cb3_row1_col6, #T_a7cb3_row2_col0, #T_a7cb3_row2_col1, #T_a7cb3_row2_col2, #T_a7cb3_row2_col3, #T_a7cb3_row2_col4, #T_a7cb3_row2_col5, #T_a7cb3_row2_col6, #T_a7cb3_row3_col0, #T_a7cb3_row3_col1, #T_a7cb3_row3_col2, #T_a7cb3_row3_col3, #T_a7cb3_row3_col4, #T_a7cb3_row3_col5, #T_a7cb3_row3_col6, #T_a7cb3_row4_col0, #T_a7cb3_row4_col1, #T_a7cb3_row4_col2, #T_a7cb3_row4_col3, #T_a7cb3_row4_col4, #T_a7cb3_row4_col5, #T_a7cb3_row4_col6, #T_a7cb3_row5_col0, #T_a7cb3_row5_col1, #T_a7cb3_row5_col2, #T_a7cb3_row5_col3, #T_a7cb3_row5_col4, #T_a7cb3_row5_col5, #T_a7cb3_row5_col6, #T_a7cb3_row6_col0, #T_a7cb3_row6_col1, #T_a7cb3_row6_col2, #T_a7cb3_row6_col3, #T_a7cb3_row6_col4, #T_a7cb3_row6_col5, #T_a7cb3_row6_col6, #T_a7cb3_row7_col0, #T_a7cb3_row7_col1, #T_a7cb3_row7_col2, #T_a7cb3_row7_col3, #T_a7cb3_row7_col4, #T_a7cb3_row7_col5, #T_a7cb3_row7_col6, #T_a7cb3_row8_col0, #T_a7cb3_row8_col1, #T_a7cb3_row8_col2, #T_a7cb3_row8_col3, #T_a7cb3_row8_col4, #T_a7cb3_row8_col5, #T_a7cb3_row8_col6, #T_a7cb3_row9_col0, #T_a7cb3_row9_col1, #T_a7cb3_row9_col2, #T_a7cb3_row9_col3, #T_a7cb3_row9_col4, #T_a7cb3_row9_col5, #T_a7cb3_row9_col6, #T_a7cb3_row10_col0, #T_a7cb3_row10_col1, #T_a7cb3_row10_col2, #T_a7cb3_row10_col3, #T_a7cb3_row10_col4, #T_a7cb3_row10_col5, #T_a7cb3_row10_col6, #T_a7cb3_row11_col0, #T_a7cb3_row11_col1, #T_a7cb3_row11_col2, #T_a7cb3_row11_col3, #T_a7cb3_row11_col4, #T_a7cb3_row11_col5, #T_a7cb3_row11_col6, #T_a7cb3_row12_col0, #T_a7cb3_row12_col1, #T_a7cb3_row12_col2, #T_a7cb3_row12_col3, #T_a7cb3_row12_col4, #T_a7cb3_row12_col5, #T_a7cb3_row12_col6, #T_a7cb3_row13_col0, #T_a7cb3_row13_col1, #T_a7cb3_row13_col2, #T_a7cb3_row13_col3, #T_a7cb3_row13_col4, #T_a7cb3_row13_col5, #T_a7cb3_row13_col6, #T_a7cb3_row14_col0, #T_a7cb3_row14_col1, #T_a7cb3_row14_col2, #T_a7cb3_row14_col3, #T_a7cb3_row14_col4, #T_a7cb3_row14_col5, #T_a7cb3_row14_col6, #T_a7cb3_row15_col0, #T_a7cb3_row15_col1, #T_a7cb3_row15_col2, #T_a7cb3_row15_col3, #T_a7cb3_row15_col4, #T_a7cb3_row15_col5, #T_a7cb3_row15_col6, #T_a7cb3_row16_col0, #T_a7cb3_row16_col1, #T_a7cb3_row16_col2, #T_a7cb3_row16_col3, #T_a7cb3_row16_col4, #T_a7cb3_row16_col5, #T_a7cb3_row16_col6, #T_a7cb3_row17_col0, #T_a7cb3_row17_col1, #T_a7cb3_row17_col2, #T_a7cb3_row17_col3, #T_a7cb3_row17_col4, #T_a7cb3_row17_col5, #T_a7cb3_row17_col6 {
#   text-align: left;
# }
# #T_a7cb3_row0_col1, #T_a7cb3_row0_col2, #T_a7cb3_row0_col3, #T_a7cb3_row0_col4, #T_a7cb3_row0_col5, #T_a7cb3_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_a7cb3_row0_col7, #T_a7cb3_row1_col7, #T_a7cb3_row2_col7, #T_a7cb3_row3_col7, #T_a7cb3_row4_col7, #T_a7cb3_row6_col7, #T_a7cb3_row7_col7, #T_a7cb3_row8_col7, #T_a7cb3_row9_col7, #T_a7cb3_row10_col7, #T_a7cb3_row11_col7, #T_a7cb3_row12_col7, #T_a7cb3_row13_col7, #T_a7cb3_row14_col7, #T_a7cb3_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_a7cb3_row5_col7, #T_a7cb3_row15_col7, #T_a7cb3_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_a7cb3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7cb3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a7cb3_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a7cb3_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a7cb3_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a7cb3_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a7cb3_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a7cb3_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_a7cb3_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7cb3_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_a7cb3_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_a7cb3_row0_col1" class="data row0 col1" >0.6434</td>
#       <td id="T_a7cb3_row0_col2" class="data row0 col2" >1.4033</td>
#       <td id="T_a7cb3_row0_col3" class="data row0 col3" >0.8835</td>
#       <td id="T_a7cb3_row0_col4" class="data row0 col4" >0.9302</td>
#       <td id="T_a7cb3_row0_col5" class="data row0 col5" >0.1414</td>
#       <td id="T_a7cb3_row0_col6" class="data row0 col6" >0.1684</td>
#       <td id="T_a7cb3_row0_col7" class="data row0 col7" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_a7cb3_level0_row1" class="row_heading level0 row1" >llar</th>
#       <td id="T_a7cb3_row1_col0" class="data row1 col0" >Lasso Least Angle Regression</td>
#       <td id="T_a7cb3_row1_col1" class="data row1 col1" >1.5514</td>
#       <td id="T_a7cb3_row1_col2" class="data row1 col2" >5.2443</td>
#       <td id="T_a7cb3_row1_col3" class="data row1 col3" >1.9280</td>
#       <td id="T_a7cb3_row1_col4" class="data row1 col4" >0.5501</td>
#       <td id="T_a7cb3_row1_col5" class="data row1 col5" >0.3327</td>
#       <td id="T_a7cb3_row1_col6" class="data row1 col6" >0.5858</td>
#       <td id="T_a7cb3_row1_col7" class="data row1 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_a7cb3_level0_row2" class="row_heading level0 row2" >lasso</th>
#       <td id="T_a7cb3_row2_col0" class="data row2 col0" >Lasso Regression</td>
#       <td id="T_a7cb3_row2_col1" class="data row2 col1" >1.5515</td>
#       <td id="T_a7cb3_row2_col2" class="data row2 col2" >5.2449</td>
#       <td id="T_a7cb3_row2_col3" class="data row2 col3" >1.9282</td>
#       <td id="T_a7cb3_row2_col4" class="data row2 col4" >0.5499</td>
#       <td id="T_a7cb3_row2_col5" class="data row2 col5" >0.3328</td>
#       <td id="T_a7cb3_row2_col6" class="data row2 col6" >0.5858</td>
#       <td id="T_a7cb3_row2_col7" class="data row2 col7" >0.2700</td>
#     </tr>
#     <tr>
#       <th id="T_a7cb3_level0_row3" class="row_heading level0 row3" >en</th>
#       <td id="T_a7cb3_row3_col0" class="data row3 col0" >Elastic Net</td>
#       <td id="T_a7cb3_row3_col1" class="data row3 col1" >1.6069</td>
#       <td id="T_a7cb3_row3_col2" class="data row3 col2" >5.6552</td>
#       <td id="T_a7cb3_row3_col3" class="data row3 col3" >1.9891</td>
#       <td id="T_a7cb3_row3_col4" class="data row3 col4" >0.4858</td>
#       <td id="T_a7cb3_row3_col5" class="data row3 col5" >0.3454</td>
#       <td id="T_a7cb3_row3_col6" class="data row3 col6" >0.6124</td>
#       <td id="T_a7cb3_row3_col7" class="data row3 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_a7cb3_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_a7cb3_row4_col0" class="data row4 col0" >AdaBoost Regressor</td>
#       <td id="T_a7cb3_row4_col1" class="data row4 col1" >1.3394</td>
#       <td id="T_a7cb3_row4_col2" class="data row4 col2" >3.3404</td>
#       <td id="T_a7cb3_row4_col3" class="data row4 col3" >1.6642</td>
#       <td id="T_a7cb3_row4_col4" class="data row4 col4" >0.4671</td>
#       <td id="T_a7cb3_row4_col5" class="data row4 col5" >0.2501</td>
#       <td id="T_a7cb3_row4_col6" class="data row4 col6" >0.3292</td>
#       <td id="T_a7cb3_row4_col7" class="data row4 col7" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_a7cb3_level0_row5" class="row_heading level0 row5" >br</th>
#       <td id="T_a7cb3_row5_col0" class="data row5 col0" >Bayesian Ridge</td>
#       <td id="T_a7cb3_row5_col1" class="data row5 col1" >1.7059</td>
#       <td id="T_a7cb3_row5_col2" class="data row5 col2" >6.6305</td>
#       <td id="T_a7cb3_row5_col3" class="data row5 col3" >2.1198</td>
#       <td id="T_a7cb3_row5_col4" class="data row5 col4" >0.3571</td>
#       <td id="T_a7cb3_row5_col5" class="data row5 col5" >0.3673</td>
#       <td id="T_a7cb3_row5_col6" class="data row5 col6" >0.6676</td>
#       <td id="T_a7cb3_row5_col7" class="data row5 col7" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_a7cb3_level0_row6" class="row_heading level0 row6"
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

df_cleaned = df.dropna()

X = df_cleaned.drop(columns=['Max Current'])
y = df_cleaned['Max Current']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=123)

print(f"X_train shape: {X_train.shape}, X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}, y_test shape: {y_test.shape}")

df_train_combined = pd.DataFrame(X_train, columns=X.columns)
df_train_combined['Max Current'] = y_train.values

df_test_combined = pd.DataFrame(X_test, columns=X.columns)
df_test_combined['Max Current'] = y_test.values

exp = setup(data = df_train_combined, target = 'Max Current', session_id=123, verbose=False)
model = compare_models(exclude=['catboost'])
evaluate_model(model)
# Out:
# X_train shape: (46, 12), X_test shape: (12, 12)
# y_train shape: (46,), y_test shape: (12,)
# <style type="text/css">
# #T_241bf th {
#   text-align: left;
# }
# #T_241bf_row0_col0, #T_241bf_row1_col0, #T_241bf_row1_col1, #T_241bf_row1_col2, #T_241bf_row1_col3, #T_241bf_row1_col4, #T_241bf_row1_col5, #T_241bf_row1_col6, #T_241bf_row2_col0, #T_241bf_row2_col1, #T_241bf_row2_col2, #T_241bf_row2_col3, #T_241bf_row2_col4, #T_241bf_row2_col5, #T_241bf_row2_col6, #T_241bf_row3_col0, #T_241bf_row3_col1, #T_241bf_row3_col2, #T_241bf_row3_col3, #T_241bf_row3_col4, #T_241bf_row3_col5, #T_241bf_row3_col6, #T_241bf_row4_col0, #T_241bf_row4_col1, #T_241bf_row4_col2, #T_241bf_row4_col3, #T_241bf_row4_col4, #T_241bf_row4_col5, #T_241bf_row4_col6, #T_241bf_row5_col0, #T_241bf_row5_col1, #T_241bf_row5_col2, #T_241bf_row5_col3, #T_241bf_row5_col4, #T_241bf_row5_col5, #T_241bf_row5_col6, #T_241bf_row6_col0, #T_241bf_row6_col1, #T_241bf_row6_col2, #T_241bf_row6_col3, #T_241bf_row6_col4, #T_241bf_row6_col5, #T_241bf_row6_col6, #T_241bf_row7_col0, #T_241bf_row7_col1, #T_241bf_row7_col2, #T_241bf_row7_col3, #T_241bf_row7_col4, #T_241bf_row7_col5, #T_241bf_row7_col6, #T_241bf_row8_col0, #T_241bf_row8_col1, #T_241bf_row8_col2, #T_241bf_row8_col3, #T_241bf_row8_col4, #T_241bf_row8_col5, #T_241bf_row8_col6, #T_241bf_row9_col0, #T_241bf_row9_col1, #T_241bf_row9_col2, #T_241bf_row9_col3, #T_241bf_row9_col4, #T_241bf_row9_col5, #T_241bf_row9_col6, #T_241bf_row10_col0, #T_241bf_row10_col1, #T_241bf_row10_col2, #T_241bf_row10_col3, #T_241bf_row10_col4, #T_241bf_row10_col5, #T_241bf_row10_col6, #T_241bf_row11_col0, #T_241bf_row11_col1, #T_241bf_row11_col2, #T_241bf_row11_col3, #T_241bf_row11_col4, #T_241bf_row11_col5, #T_241bf_row11_col6, #T_241bf_row12_col0, #T_241bf_row12_col1, #T_241bf_row12_col2, #T_241bf_row12_col3, #T_241bf_row12_col4, #T_241bf_row12_col5, #T_241bf_row12_col6, #T_241bf_row13_col0, #T_241bf_row13_col1, #T_241bf_row13_col2, #T_241bf_row13_col3, #T_241bf_row13_col4, #T_241bf_row13_col5, #T_241bf_row13_col6, #T_241bf_row14_col0, #T_241bf_row14_col1, #T_241bf_row14_col2, #T_241bf_row14_col3, #T_241bf_row14_col4, #T_241bf_row14_col5, #T_241bf_row14_col6, #T_241bf_row15_col0, #T_241bf_row15_col1, #T_241bf_row15_col2, #T_241bf_row15_col3, #T_241bf_row15_col4, #T_241bf_row15_col5, #T_241bf_row15_col6, #T_241bf_row16_col0, #T_241bf_row16_col1, #T_241bf_row16_col2, #T_241bf_row16_col3, #T_241bf_row16_col4, #T_241bf_row16_col5, #T_241bf_row16_col6, #T_241bf_row17_col0, #T_241bf_row17_col1, #T_241bf_row17_col2, #T_241bf_row17_col3, #T_241bf_row17_col4, #T_241bf_row17_col5, #T_241bf_row17_col6 {
#   text-align: left;
# }
# #T_241bf_row0_col1, #T_241bf_row0_col2, #T_241bf_row0_col3, #T_241bf_row0_col4, #T_241bf_row0_col5, #T_241bf_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_241bf_row0_col7, #T_241bf_row2_col7, #T_241bf_row4_col7, #T_241bf_row5_col7, #T_241bf_row6_col7, #T_241bf_row7_col7, #T_241bf_row8_col7, #T_241bf_row9_col7, #T_241bf_row10_col7, #T_241bf_row11_col7, #T_241bf_row12_col7, #T_241bf_row13_col7, #T_241bf_row14_col7, #T_241bf_row15_col7, #T_241bf_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_241bf_row1_col7, #T_241bf_row3_col7, #T_241bf_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_241bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_241bf_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_241bf_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_241bf_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_241bf_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_241bf_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_241bf_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_241bf_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_241bf_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_241bf_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_241bf_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_241bf_row0_col1" class="data row0 col1" >0.8296</td>
#       <td id="T_241bf_row0_col2" class="data row0 col2" >1.9717</td>
#       <td id="T_241bf_row0_col3" class="data row0 col3" >1.0480</td>
#       <td id="T_241bf_row0_col4" class="data row0 col4" >0.9080</td>
#       <td id="T_241bf_row0_col5" class="data row0 col5" >0.1326</td>
#       <td id="T_241bf_row0_col6" class="data row0 col6" >0.1430</td>
#       <td id="T_241bf_row0_col7" class="data row0 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_241bf_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_241bf_row1_col0" class="data row1 col0" >Ridge Regression</td>
#       <td id="T_241bf_row1_col1" class="data row1 col1" >1.4141</td>
#       <td id="T_241bf_row1_col2" class="data row1 col2" >4.0402</td>
#       <td id="T_241bf_row1_col3" class="data row1 col3" >1.7424</td>
#       <td id="T_241bf_row1_col4" class="data row1 col4" >0.7083</td>
#       <td id="T_241bf_row1_col5" class="data row1 col5" >0.2672</td>
#       <td id="T_241bf_row1_col6" class="data row1 col6" >0.3252</td>
#       <td id="T_241bf_row1_col7" class="data row1 col7" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_241bf_level0_row2" class="row_heading level0 row2" >br</th>
#       <td id="T_241bf_row2_col0" class="data row2 col0" >Bayesian Ridge</td>
#       <td id="T_241bf_row2_col1" class="data row2 col1" >1.4208</td>
#       <td id="T_241bf_row2_col2" class="data row2 col2" >4.0516</td>
#       <td id="T_241bf_row2_col3" class="data row2 col3" >1.7479</td>
#       <td id="T_241bf_row2_col4" class="data row2 col4" >0.7035</td>
#       <td id="T_241bf_row2_col5" class="data row2 col5" >0.2667</td>
#       <td id="T_241bf_row2_col6" class="data row2 col6" >0.3285</td>
#       <td id="T_241bf_row2_col7" class="data row2 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_241bf_level0_row3" class="row_heading level0 row3" >lasso</th>
#       <td id="T_241bf_row3_col0" class="data row3 col0" >Lasso Regression</td>
#       <td id="T_241bf_row3_col1" class="data row3 col1" >1.6493</td>
#       <td id="T_241bf_row3_col2" class="data row3 col2" >5.5420</td>
#       <td id="T_241bf_row3_col3" class="data row3 col3" >2.0006</td>
#       <td id="T_241bf_row3_col4" class="data row3 col4" >0.6779</td>
#       <td id="T_241bf_row3_col5" class="data row3 col5" >0.2573</td>
#       <td id="T_241bf_row3_col6" class="data row3 col6" >0.2965</td>
#       <td id="T_241bf_row3_col7" class="data row3 col7" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_241bf_level0_row4" class="row_heading level0 row4" >llar</th>
#       <td id="T_241bf_row4_col0" class="data row4 col0" >Lasso Least Angle Regression</td>
#       <td id="T_241bf_row4_col1" class="data row4 col1" >1.6493</td>
#       <td id="T_241bf_row4_col2" class="data row4 col2" >5.5420</td>
#       <td id="T_241bf_row4_col3" class="data row4 col3" >2.0006</td>
#       <td id="T_241bf_row4_col4" class="data row4 col4" >0.6779</td>
#       <td id="T_241bf_row4_col5" class="data row4 col5" >0.2573</td>
#       <td id="T_241bf_row4_col6" class="data row4 col6" >0.2965</td>
#       <td id="T_241bf_row4_col7" class="data row4 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_241bf_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_241bf_row5_col0" class="data row5 col0" >AdaBoost Regressor</td>
#       <td id="T_241bf_row5_col1" class="data row5 col1" >1.3967</td>
#       <td id="T_241bf_row5_col2" class="data row5 col2" >4.3389</td>
#       <td id="T_241bf_row5_col3" class="data row5 col3" >1.7769</td>
#       <td id="T_241bf_row5_col4" class="data row5 col4" >0.6687</td>
#       <td id="T_241bf_row5_col5" class="data row5 col5" >0.2509</td>
#       <td id="T_241bf_row5_col6" class="data row5 col6" >0.2828</td>
#       <td id="T_241bf_row5_col7" class="data row5 col7" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_241bf_level0_row6" class="row_heading level
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
y_pred = predict_model(model, data=df_test_combined)
df_test_combined['Predicted Max Current'] = y_pred['prediction_label']

plt.figure(figsize=(10, 6))
plt.rcParams.update({'font.size': 12, 'font.family': 'serif'})
plt.scatter(df_test_combined['Max Current'], df_test_combined['Predicted Max Current'], color='blue', alpha=0.7, label='Predicted vs Actual')
plt.plot([df_test_combined['Max Current'].min(), df_test_combined['Max Current'].max()],
         [df_test_combined['Max Current'].min(), df_test_combined['Max Current'].max()],
         color='red', linestyle='--', label='Perfect Prediction')
plt.xlabel('Actual Max Current')
plt.ylabel('Predicted Max Current')
plt.title('Actual vs Predicted Max Current')
plt.legend()
plt.grid(False)
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_59353">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_59353_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_59353_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_59353_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_59353_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_59353_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_59353_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_59353_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59353_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_59353_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_59353_row0_col1" class="data row0 col1" >0.9716</td>
#       <td id="T_59353_row0_col2" class="data row0 col2" >1.6289</td>
#       <td id="T_59353_row0_col3" class="data row0 col3" >1.2763</td>
#       <td id="T_59353_row0_col4" class="data row0 col4" >0.9471</td>
#       <td id="T_59353_row0_col5" class="data row0 col5" >0.3639</td>
#       <td id="T_59353_row0_col6" class="data row0 col6" >0.6982</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_test_combined
# Out:
#           AC        CB         G      MnO2  Pour Density  Surface Area  \
# 0   2.610464 -1.388022 -1.225312 -1.378405     -0.596576      2.466945
# 1   1.478122 -0.271784 -1.225312 -1.378405     -0.769130      1.345278
# 2  -0.560093 -0.197369  0.774807  0.725476      0.404705     -0.493911
# 3  -1.164008 -1.388022  2.621071 -1.378405     -2.158231     -1.321795
# 4   0.874207 -1.201982  0.351705  0.725476      0.731787      0.932351
# 5  -0.937540 -1.127566  2.121041  0.725476      0.001922     -0.885248
# 6  -1.164008  1.216532 -0.071397 -1.378405     -1.467700     -1.286900
# 7  -1.164008 -0.271784  1.467156  0.725476      0.135111     -1.101107
# 8   0.723228 -0.197369 -0.532963  0.725476      0.935668      0.794260
# 9   1.289399 -0.271784 -1.032992  0.725476      1.150187      1.361574
# 10 -1.164008  2.332769 -1.225312  0.725476      0.825642     -1.066212
# 11  2.610464 -1.388022 -1.225312  0.725476      1.400825      2.672679
#
#     Dry Conductivity  Electrolyte Uptake  Water Uptake  Voltage Drop  \
# 0          -0.929020            3.166763      3.203333      2.663380
# 1          -0.456136            0.816350      1.417814     -0.031461
# 2          -0.172854           -0.651198     -0.540323     -0.612869
# 3           0.068626           -0.575281     -0.386474      1.977233
# 4          -0.852528            1.728019     -0.077880      0.389168
# 5          -0.199013           -0.086277     -0.652918     -0.457658
# 6           3.300612           -1.842501     -1.851670      0.101960
# 7           0.509760           -0.415857     -1.252705     -0.741230
# 8          -0.734003            0.689403     -0.380941     -0.185204
# 9          -0.890176            1.043302     -0.031574      0.150048
# 10          0.654022            0.726262     -0.613053     -0.821167
# 11         -0.964347            2.023078      1.226302      4.707068
#
#     Cell Resistance  Wet Conductivity  Max Current  Predicted Max Current
# 0          2.404769         -1.057577     0.730000               2.725684
# 1         -0.128716         -0.575145     2.588088               2.709315
# 2         -0.478753          0.778218    10.246029              11.055062
# 3          1.500123         -0.997537     0.980588               2.434382
# 4          0.006795         -0.945776     3.131912               4.113572
# 5         -0.369398         -0.549740     8.335441               7.607506
# 6         -0.144777         -0.517016     2.030000               2.550779
# 7         -0.504345          1.473521    14.387255              14.702779
# 8         -0.307022         -0.663031     5.121029               5.128678
# 9         -0.195018         -0.844392     3.625147               3.777896
# 10        -0.501679          1.547571    18.317206              15.563060
# 11         5.751117         -1.117981     0.575000               2.393821
